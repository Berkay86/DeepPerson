# %% [markdown]
# <a href="https://colab.research.google.com/github/Berkay86/DeepPerson/blob/main/g%C3%BCncel_programramam_dilleri_dersi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def toplama(a,b):
     return a+b 

sonuc = toplama(1752,1324)
print(sonuc)
# Out:
# 3076

# %%
def topla(a,b):
  c= a + b
  print(c)

topla(2,3)
# Out:
# 5

# %%
def topla(a,b): #Fonksiyonumuzun ne işe yarayacağını belirttik.
  
  c = a+b #Fonksiyonun, içeri gelen a ve b sayılarıyla
          #ne yapacağına karar verdik.
  
  return c # a ve b sayılarının toplamıyla oluşan c sayısının 
           #istenilen yere yani toplam'a ulaştırılmasını sağladık.


toplam = topla(3,2)
print(toplam)
# Out:
# 5

# %% [markdown]
# toplama adında bir fonksiyon hazırlayıp bu fonksiyon aracılığı ile 1752 ile 1324 nin toplamını sonuc ismi ile yazdıran komutu hazırlayın

# %%
a=35
b=54
kalan = ((a+b)%7)
print (kalan)
f = 1
for i in range(kalan):
    f = f * (i + 1)

print("Kalan Faktoriyel : ", f)
# Out:
# 5
# Kalan Faktoriyel :  120

# %%
def kalanfaktoriyel(): #fonksiyon adı
    kalan = ((a+b)%7)
    print (kalan)
    f = 1
    for i in range(kalan):
        f = f * (i + 1)


    print("Kalan Faktoriyel : ", f)

a = 35
b = 54
kalanfaktoriyel()
# Out:
# 5
# Kalan Faktoriyel :  120

# %%
def kalanfaktoriyel():
    kalan = ((a+b)%7)
    print (kalan)
    f = 1
    for i in range(kalan):
        f = f * (i + 1)
    return f #fonksiyona atama

a = 35
b = 54

print(kalanfaktoriyel()*2)
# Out:
# 5
# 240

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from numpy import random
sayi1=random.rand()
sayi2=random.randint(100)
sayi3=random.randint(50,150,(2,1))
sayi4=random.randn(50)
sayi4
# Out:
# 50

# %%
sayi3=random.rand(10,20,size=(2,3))
sayi3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-515f2a12a263> in <module>
# ----> 1 sayi3=random.rand(10,20,size=(2,3))
#       2 sayi3
#
# TypeError: rand() got an unexpected keyword argument 'size'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-763b6d542e5f> in <module>
# ----> 1 random.randint(45, 500)
#
# NameError: name 'random' is not defined

# %%
import random
print(random.random())
random.uniform(0.5, 1.5)
# Out:
# 0.6295659036074833
# 0.989653011834809

# %%
random.randint(45, 500)
# Out:
# 406

# %%
liste = ['ali', 'veli', 'ahmet', 'mehmet', 'celal', 'selin', 'nihat']

random.choice(liste)
# Out:
# 'selin'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png](data:image/png;base64,...))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
a=np.random.uniform(0,10,10000)
sns.histplot(a)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from numpy import random
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(random.normal(loc=0,scale=1,size=(2,3)),hist=False)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Veriye github üzerinden ulaşalım
url = "https://github.com/yigitsener/machine-learning/blob/master/data/lessons.csv"
df = pd.read_csv(url + "?raw=true", error_bad_lines=False)

# Kolon isimlerini değiştirme
df = df.rename(columns = {"Maths" : "Matematik",
                     "English" : "İngilizce",
                     "History" : "Tarih"})

# satır ve kolon sayısı
print(f"satır sayısı: {df.shape[0]}, kolon sayısı: {df.shape[0]}")
# ÇIKTI: satır sayısı: 100, kolon sayısı: 100

# Veri setine ait ilk 5 satır
print(df.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# satır sayısı: 100, kolon sayısı: 100
#    Matematik  İngilizce      Tarih
# 0  67.970442  60.990250  72.200954
# 1  58.438226  64.157607  62.687182
# 2  82.354172  62.998874  50.171015
# 3  72.909983  64.255032  62.686110
# 4  81.140560  64.819401  57.546319

# %%
# Betimleyici İstatistikler
print(df.describe())
# Out:
#         Matematik   İngilizce       Tarih
# count  100.000000  100.000000  100.000000
# mean    70.260026   62.564380   62.306433
# std      8.490178    1.813402   17.354135
# min     50.592003   60.160859    4.592358
# 25%     64.705280   61.284863   53.810693
# 50%     70.277253   62.167855   64.672982
# 75%     76.986152   63.591046   74.121710
# max     89.627868   67.829394   86.833889

# %%
# Histogram plot parametreleri
_, bins, _ = plt.hist(df.Matematik, bins = 10,
                      density = 1, alpha = 0.5,
                      ec= 'black' )

# Çan eğrisi için en uygun değerler
mu, sigma = stats.norm.fit(df.Matematik)
best_fit_line = stats.norm.pdf(bins, mu, sigma)

# Çan eğrisi gösterimi
plt.plot(bins, best_fit_line, 'g-o')
plt.xlabel("Not Değerleri")
plt.ylabel("Frekans")
plt.show()

# %%
sayı=[]
while True:
    y=input("sayı giriniz:")
    x= y.lower()
    if x!="exit":
        sayı.append(float(x))
    else:
        print("sayı girişi sonlandı")
        break
sayı.sort()
range=sayı[len(sayı)-1]-sayı[0]
print("girilen sayılar için açıklık değeri:", range)
# Out:
# sayı giriniz:5
# sayı giriniz:10
# sayı giriniz:15
# sayı giriniz:60
# sayı giriniz:exit
# sayı girişi sonlandı
# girilen sayılar için açıklık değeri: 55.0

# %%
sayı
# Out:
# [5.0, 10.0, 50.0, 70.0]
