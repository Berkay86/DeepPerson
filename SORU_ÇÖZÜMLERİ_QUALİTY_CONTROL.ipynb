# %% [markdown]
# <a href="https://colab.research.google.com/github/Berkay86/DeepPerson/blob/main/SORU_%C3%87%C3%96Z%C3%9CMLER%C4%B0_QUAL%C4%B0TY_CONTROL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
from math import sqrt
import matplotlib.pyplot as plt

X1=[]
X=[7,5,11,13,9,12,10,10,6,14,9,13,8,11,12,10,9,12,14,12,13,7,9,12,8,14,12,12,11,13]
UCL1=[]
CL1=[]
LCL1=[]
c=1
n=1000
sigma=3
C=[]
while c<=True:
  X1=[]
  
  for i in X:
    X1.append(i/50)

  ptahminedici=sum(X)/(n*len(X))
  UCL=ptahminedici+sigma*sqrt((ptahminedici*(1-ptahminedici)/n))
  UCL1.append(UCL)
  CL=ptahminedici
  CL1.append(CL)
  LCL=ptahminedici-sigma*sqrt((ptahminedici*(1-ptahminedici)/n))
  LCL1.append(LCL)
  print(X1)
  for y in X:
    if y/n>=UCL:
        X.remove(y)
        X1.remove(y/n)
        
    elif y/n<=LCL:
        X.remove(y)   
        X1.remove(y/n)
  C.append(c)
  c+=1

plt.plot([d for d in range(1,len(X)+1)],X1)
print("LCL: ",LCL1)
print("UCL: ",UCL1)
print("CL: ",CL1)
# Out:
# [0.14, 0.1, 0.22, 0.26, 0.18, 0.24, 0.2, 0.2, 0.12, 0.28, 0.18, 0.26, 0.16, 0.22, 0.24, 0.2, 0.18, 0.24, 0.28, 0.24, 0.26, 0.14, 0.18, 0.24, 0.16, 0.28, 0.24, 0.24, 0.22, 0.26]
# LCL:  [0.0008846122053723458]
# UCL:  [0.020315387794627653]
# CL:  [0.0106]

# %%
from math import sqrt
import matplotlib.pyplot as plt

X1=[]
X=[7,5,11,13,9,12,10,10,6,14,9,13,8,11,12,10,9,12,14,12,13,7,9,12,8,14,12,12,11,13]
UCL1=[]
CL1=[]
LCL1=[]
c=1
n=1000
C=[]
while c<=True:
  X1=[]
  
  for i in X:
    X1.append(i/n)
    
  ptahminedici=sum(X)/(n*len(X))
  print(ptahminedici)
  UCL=n*ptahminedici+3*sqrt((n*ptahminedici*(1-ptahminedici)))
  UCL1.append(UCL)
  CL=n*ptahminedici
  CL1.append(CL)
  LCL=n*ptahminedici-3*sqrt((n*ptahminedici*(1-ptahminedici)))
  LCL1.append(LCL)
  for y in X:
    if y/n>=UCL:
        X.remove(y)
        X1.remove(y/n)
    elif y/n<=LCL:
        X.remove(y)   
        X1.remove(y/n)
  C.append(c)
  c+=1

plt.plot([d for d in range(1,len(X)+1)],X1)
print("LCL: ",LCL1)
print("UCL: ",UCL1)
print("CL: ",CL1)
# Out:
# 0.0106
# LCL:  [0.8846122053723455]
# UCL:  [20.315387794627654]
# CL:  [10.6]

# %%
3*sqrt((n*ptahminedici*(1-ptahminedici)))
# Out:
# 9.715387794627654

# %%
from math import sqrt
import matplotlib.pyplot as plt

X=[7,5,11,13,9,12,10,10,6,14,9,13,8,11,12,10,9,12,14,12,13,7,9,12,8,14,12,12,11,13]
UCL1=[]
CL1=[]
LCL1=[]
c=1
n=50
C=[]
while c<=True:
  X1=[]
  
  for i in X:
    X1.append(i/n)

  ptahminedici=sum(X1)/(len(X1))
  UCL=ptahminedici+3*sqrt(ptahminedici/50)
  UCL1.append(UCL)
  CL=ptahminedici
  CL1.append(CL)
  LCL=ptahminedici-3*sqrt(ptahminedici/50)
  LCL1.append(LCL)
  for y in X:
    if y/n>=UCL:
        X.remove(y)
        X1.remove(y/n)
    elif y/n<=LCL:
        X.remove(y)   
        X1.remove(y/n)
  C.append(c)
  c+=1
for LCL2 in LCL1:
  if LCL2<0:
    LCL2=0
    LCL1=LCL2
plt.plot([d for d in range(1,len(X)+1)],X1)
print("LCL: ",LCL1)
print("UCL: ",UCL1)
print("CL:  " ,CL1)
# Out:
# LCL:  [0.01665415284680355]
# UCL:  [0.4073458471531965]
# CL:   [0.21200000000000002]

# %%
from math import sqrt
import matplotlib.pyplot as plt

X=[7,5,11,13,9,12,10,10,6,14,9,13,8,11,12,10,9,12,14,12,13,7,9,12,8,14,12,12,11,13]
UCL1=[]
CL1=[]
LCL1=[]
c=1
n=1000
while c<=True:

  ptahminedici=sum(X)/(len(X))
  UCL=ptahminedici+3*sqrt(ptahminedici)
  UCL1.append(UCL)
  CL=ptahminedici
  CL1.append(CL)
  LCL=ptahminedici-3*sqrt(ptahminedici)
  LCL1.append(LCL)
  for y in X:
    if y/n>=UCL:
        X.remove(y)
    elif y/n<=LCL:
        X.remove(y)   

  c+=1

plt.plot([d for d in range(1,len(X)+1)],X)
print("LCL1: ",LCL1)
print("UCL1: ",UCL1)
print("CL1: ",CL1)
# Out:
# LCL1:  [0.8327076423401767]
# UCL1:  [20.36729235765982]
# CL1:  [10.6]

# %%
from math import comb
import numpy as np
buyuk=[]
buyuk2=[]
kucuk=[]
kucuk2=[]

kucuk1=1
buyuk1=20
y=float(input("p Değerini Giriniz: "))
for i in range(0,buyuk1+1):
    buyuk.append(comb(50,i)*((y)**(i))*((1-y)**(50-i)))
    buyuk2.append(sum(buyuk))

for i in range(0,kucuk1+1):
    kucuk.append(comb(50,i)*((y)**(i))*((1-y)**(50-i)))
    kucuk2.append(sum(kucuk))

beta=buyuk2[len(buyuk2)-1]-kucuk2[len(kucuk2)-1]

ARL=1/(1-round(beta,4))

print("ARL: ",ARL)
print(f"P(D<{buyuk1}): ",buyuk2[len(buyuk2)-1])
print(f"P(D<={kucuk1}): ",kucuk2[len(kucuk2)-1])
print("BETA: ",round(beta,4))
# Out:
# p Değerini Giriniz: 7
# ARL:  -1.8880734464450794e-54
# P(D<20):  5.296404130266977e+53
# P(D<=1):  -4.634145990797981e+40
# BETA:  5.29640413026744e+53

# %%
import numpy as np
from math import comb
n=int(input("n değerini giriniz"))
c=int(input("c değerini giriniz"))
h=[]
h1=[]
for y in np.arange(0.01,1,0.01):
  for i in range(c+1):
     if y==0.15:
        h.append(comb(n,i)*((y)**(i))*((1-y)**(n-i)))
f=0
g=[]
while f<len(h):
  g.append(sum(h[f:(f+(c+1))]))
  f+=(c+1)
h
# Out:
# n değerini giriniz50
# c değerini giriniz1
# []

# %%
0.0756*0.3660
# Out:
# 0.0276696

# %%
N=int(input("n değerini giriniz"))
t=[]
u=0
while u<8:
  for y in np.arange(0.01,0.09,0.01):
        t.append(((g[u]*y*(N-n))/N))
        u+=1
# Out:
# n değerini giriniz10000

# %%
plt.plot([y for y in np.arange(0,0.09,0.01)],t)

# %%
ATI=[]
ATI1=[]
ATI2=[]
for h in g: 
  ATI.append(n+(1-h)*(N-n))
  ATI1.append(n+(1-h)*(5000-n))
  ATI2.append(n+(1-h)*(1000-n))

# %%
plt.plot([y for y in np.arange(0,0.10,0.01)],ATI[1:11])
plt.plot([y for y in np.arange(0,0.10,0.01)],ATI1[1:11])
plt.plot([y for y in np.arange(0,0.10,0.01)],ATI2[1:11])

# %%
import math 
p1=float(input("p1 değerini giriniz"))
p2=float(input("p2 değerini giriniz"))
alfa=float(input("alfa değerini giriniz"))
beta=float(input("beta değerini giriniz"))
k=math.log((p2*(1-p1))/(p1*(1-p2)),10)
h7=math.log((1-alfa)/beta,10)/k
h8=math.log((1-beta)/alfa,10)/k
s=math.log((1-p1)/(1-p2),10)/k

print("s",s)
print("k",k)
print("h1",h7)
print("h2",h8)
# Out:
# p1 değerini giriniz0.01
# p2 değerini giriniz0.06
# alfa değerini giriniz0.05
# beta değerini giriniz0.10
# s 0.02811103414130118
# k 0.8006585913814948
# h1 1.2211492086806142
# h2 1.5677999569546845

# %%
import matplotlib.pyplot as plt
XA=[]
XR=[]
for n in range(47):
  XA.append(-h7+s*n)
  XR.append(h8+s*n)

plt.plot([n for n in range(47)],XA)
plt.plot([n for n in range(47)],XR)
