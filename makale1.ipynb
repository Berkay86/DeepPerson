# %% [markdown]
# <a href="https://colab.research.google.com/github/Berkay86/DeepPerson/blob/main/makale1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
import PyPDF2
from PyPDF2 import PdfReader
import nltk 
nltk.download('punkt')
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
pdfFileObj = open("Fundamentals of the interferometric fiber-optic gyroscope.pdf", 'rb')

# %%
def reset_eof_of_pdf_return_stream(pdf_stream_in:list):
    # find the line position of the EOF
    for i, x in enumerate(txt[::-1]):
        if b'%%EOF' in x:
            actual_line = len(pdf_stream_in)-i
            print(f'EOF found at line position {-i} = actual {actual_line}, with value {x}')
            break

    # return the list up to that point
    return pdf_stream_in[:actual_line]

# opens the file for reading
with open('Fundamentals of the interferometric fiber-optic gyroscope.pdf', 'rb') as p:
    txt = (p.readlines())

# get the new list terminating correctly
txtx = reset_eof_of_pdf_return_stream(txt)

# write to new pdf
with open('Fundamentals of the interferometric fiber-optic gyroscope.pdf', 'wb') as f:
    f.writelines(txtx)

fixed_pdf = PyPDF2.PdfFileReader('Fundamentals of the interferometric fiber-optic gyroscope.pdf')
# Out:
# EOF found at line position 0 = actual 2392, with value b'%%EOF\r\n'

# %%
reset_eof_of_pdf_return_stream("Fundamentals of the interferometric fiber-optic gyroscope.pdf")
# Out:
# EOF found at line position 0 = actual 61, with value b'%%EOF\r\n'
# 'Fundamentals of the interferometric fiber-optic gyroscope.pdf'

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
numPages = pdfReader.numPages

# %%
text = ""
for i in range(numPages - 2):
    # her sayfa için text okunuyor
    pageText = pdfReader.getPage(i).extractText()
    # okunan text eskisine eklenir
    text = text + " " + (pageText)

# %%
text[500000:]
# Out:
# ''

# %%
words_list = nltk.tokenize.word_tokenize(text, language="english")
print(words_list[:1000])
# Out:
# ['OPTICAL', 'REVIEW', 'Vol', '.', '4', ',', 'No', '.', 'lA', '(', '1997', ')', '20-27', 'Review', 'Fundamentals', 'of', 'the', 'Interferometric', 'Fiber-Optic', 'Gyroscope', 'Herve', 'C.', 'LEFEVRE', 'Plwtonetics', ',', '52', ',', 'Avenue', 'de', "l'Eurape", ',', '78160', 'Marly-le-Roi', ',', 'France', '(', 'Received', 'July', '24', ',', '1996', ';', 'Accepted', 'September', '9', ',', '1996', ')', 'This', 'paper', 'reviews', 'the', 'basics', 'of', 'the', 'interferometric', 'fiber-optic', 'gyroscope', ':', 'fundamental', 'principle', 'based', 'on', 'Sagnac', 'effect', ',', 'importance', 'of', 'reciprocity', 'and', 'single-mode', 'propagation', ',', 'analysis', 'of', 'coherence', 'and', 'polarization', 'problems', ',', 'signal', 'processing', 'techniques', '.', 'it', 'also', 'describes', 'the', 'technological', 'progresses', 'of', 'guided-wave', 'compo\xad', 'nents', '(', 'single-mode', 'optical', 'fiber', ',', 'semi-conductor', 'diode', 'source', ',', 'integrated', 'optics', ',', 'in-
# ...

# %%
print(len(words_list))
# Out:
# 4733

# %%
from itertools import count
from nltk.corpus.reader import wordlist

# %%
words_list = [word.lower() for word in words_list if word.isalpha()]
print(words_list[:1000])
print(len(words_list))
# Out:
# ['optical', 'review', 'vol', 'no', 'la', 'review', 'fundamentals', 'of', 'the', 'interferometric', 'gyroscope', 'herve', 'lefevre', 'plwtonetics', 'avenue', 'de', 'france', 'received', 'july', 'accepted', 'september', 'this', 'paper', 'reviews', 'the', 'basics', 'of', 'the', 'interferometric', 'gyroscope', 'fundamental', 'principle', 'based', 'on', 'sagnac', 'effect', 'importance', 'of', 'reciprocity', 'and', 'propagation', 'analysis', 'of', 'coherence', 'and', 'polarization', 'problems', 'signal', 'processing', 'techniques', 'it', 'also', 'describes', 'the', 'technological', 'progresses', 'of', 'nents', 'optical', 'fiber', 'diode', 'source', 'integrated', 'optics', 'fiber', 'components', 'finally', 'recent', 'trends', 'like', 'configurations', 'and', 'doped', 'fiber', 'source', 'are', 'presented', 'key', 'words', 'gyroscope', 'fiber', 'optics', 'interferometry', 'sensor', 'introduction', 'over', 'the', 'last', 'twenty', 'years', 'the', 'interferometric', 'optic', 'gyroscope', 'has',
# ...

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
stop_words = set(nltk.corpus.stopwords.words('english'))

words_list = [word for word in words_list if not word  in stop_words]
print(words_list[:1000])
# Out:
# ['optical', 'review', 'vol', 'la', 'review', 'fundamentals', 'interferometric', 'gyroscope', 'herve', 'lefevre', 'plwtonetics', 'avenue', 'de', 'france', 'received', 'july', 'accepted', 'september', 'paper', 'reviews', 'basics', 'interferometric', 'gyroscope', 'fundamental', 'principle', 'based', 'sagnac', 'effect', 'importance', 'reciprocity', 'propagation', 'analysis', 'coherence', 'polarization', 'problems', 'signal', 'processing', 'techniques', 'also', 'describes', 'technological', 'progresses', 'nents', 'optical', 'fiber', 'diode', 'source', 'integrated', 'optics', 'fiber', 'components', 'finally', 'recent', 'trends', 'like', 'configurations', 'doped', 'fiber', 'source', 'presented', 'key', 'words', 'gyroscope', 'fiber', 'optics', 'interferometry', 'sensor', 'introduction', 'last', 'twenty', 'years', 'interferometric', 'optic', 'gyroscope', 'evolved', 'pioneering', 'physics', 'practical', 'device', 'production', 'made', 'possible', 'refined', 'analysis', 'system', 'architecture'
# ...

# %%
wn_lemma = nltk.WordNetLemmatizer()
words_list = [wn_lemma.lemmatize(word) for word in words_list]
print(words_list[:1000])
# Out:
# ['optical', 'review', 'vol', 'la', 'review', 'fundamental', 'interferometric', 'gyroscope', 'herve', 'lefevre', 'plwtonetics', 'avenue', 'de', 'france', 'received', 'july', 'accepted', 'september', 'paper', 'review', 'basic', 'interferometric', 'gyroscope', 'fundamental', 'principle', 'based', 'sagnac', 'effect', 'importance', 'reciprocity', 'propagation', 'analysis', 'coherence', 'polarization', 'problem', 'signal', 'processing', 'technique', 'also', 'describes', 'technological', 'progress', 'nents', 'optical', 'fiber', 'diode', 'source', 'integrated', 'optic', 'fiber', 'component', 'finally', 'recent', 'trend', 'like', 'configuration', 'doped', 'fiber', 'source', 'presented', 'key', 'word', 'gyroscope', 'fiber', 'optic', 'interferometry', 'sensor', 'introduction', 'last', 'twenty', 'year', 'interferometric', 'optic', 'gyroscope', 'evolved', 'pioneering', 'physic', 'practical', 'device', 'production', 'made', 'possible', 'refined', 'analysis', 'system', 'architecture', 'optimal', 's
# ...

# %%
check_words = nltk.corpus.words.words()
words_list = [word for word in words_list if word in check_words]
print(words_list[:10])
# Out:
# ['optical', 'review', 'vol', 'la', 'review', 'fundamental', 'gyroscope', 'avenue', 'de', 'received']

# %%
x=[]
for word in words_list:
    if word !="fig":
        x.append(word)
  
wordcloud = WordCloud(width=1000, height=500, regexp=r"\w[\w' ]+").generate("+".join(x[:1000]))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
