# %% [markdown]
# <a href="https://colab.research.google.com/github/Berkay86/DeepPerson/blob/main/Satran%C3%A71.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import numpy as np
import pandas as pd
import cv2
import random
import matplotlib.pyplot as plt
from zipfile import ZipFile
from google.colab import files
import os

# %%
file2 = "/content/GAMES.zip"

# %%
with ZipFile(file2, 'r') as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# GAMES/                                         2022-12-07 22:59:44            0
# GAMES/GAME1/                                   2022-12-07 23:00:00            0
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (1...e7-e5).jpg 2022-12-07 13:32:26        72733
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (1.e2-e4).jpg 2022-12-07 13:42:38        72653
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (10...Bf8xd6).jpg 2022-12-07 13:34:16        67733
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (10.e5xd6).jpg 2022-12-07 13:34:10        68634
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (11...Bc8-f5).jpg 2022-12-07 13:34:24        67088
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (11.Qd1xd4).jpg 2022-12-07 13:34:20        67050
# GAMES/GAME1/Bird Henry Edward - Anderssen Adolf (12...0-0-0).jpg 2022-12-07 13:34:34        66860
# ...

# %%
paths = os.listdir('GAMES')
paths
# Out:
# ['GAME1',
#  'GAME7',
#  'GAME4',
#  'GAME11',
#  'GAME15',
#  'GAME2',
#  'GAME13',
#  'GAME9',
#  'GAME10',
#  'GAME3',
#  'GAME5',
#  'GAME6',
#  'GAME12',
#  'GAME14',
#  'GAME8']

# %%
k=[]
images = []
labels = []
m=[] 
a=[]

# %%
for i in paths:
    path0 = '/content/GAMES/'+ str(i)
    for path in os.listdir(path0):
        path = '/content/GAMES/'+ str(i) + "/" + path
        #print(path)
        img = cv2.imread(path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img,(64,64),interpolation= cv2.INTER_AREA)
        img = img/255.0
        images.append(img)
        label = path.split("(")
        m.append(label)
        for y in range(int(len(m))):
            label1=m[y][1][:2]
            labels.append(int(label1.split(".")[0]))

# %%
m1=[]
for i in paths:
    path0 = '/content/GAMES/'+ str(i)
    for path in os.listdir(path0):
        path = '/content/GAMES/'+ str(i) + "/" + path
        m1.append(cv2.imread(path))

# %%
n=[]
n2=[]
n3=[]

for i in range(0,64):
    n.append(images[30][i][0:9])
    n2.append(images[30][i][10:19])
    n3.append(images[30][i][17:24])
plt.imshow(n)

# %%
plt.imshow(n2)

# %%
n2=np.array(n2)
n2.shape
# Out:
# (64, 9)

# %%
n=np.array(n)
n.shape
# Out:
# (64, 9)

# %%
a=0
for i in range(0,64):
    if n[i] in n2[i]:
      print(n[i])
      a+=1
  
a
# Out:
# [0.30196078 0.29411765 0.29411765 0.29411765 0.29411765 0.29411765
#  0.29411765 0.29411765 0.29411765]
# [0.27843137 0.27058824 0.27058824 0.27058824 0.27058824 0.37254902
#  0.27058824 0.27058824 0.27058824]
# 2
